# %%
import pandas as pd
import numpy as np

# %%
test=pd.read_csv("test_V2.csv")
train=pd.read_csv("train_V2.csv")

# %%
train.shape
# Out:
# (4446966, 29)

# %%
test.shape
# Out:
# (1934174, 28)

# %%
pd.set_option("display.max_columns",len(train))

# %%
test.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  9329eb41e215eb  676b23c24e70d6  45b576ab7daa7f        0       0
# 1  639bd0dcd7bda8  430933124148dd  42a9a0b906c928        0       4
# 2  63d5c8ef8dfe91  0b45f5db20ba99  87e7e4477a048e        1       0
# 3  cf5b81422591d1  b7497dbdc77f4a  1b9a94f1af67f1        0       0
# 4  ee6a295187ba21  6604ce20a1d230  40754a93016066        0       4
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0        51.46      0              0      0         73           0      0
# 1       179.10      0              0      2         11           0      2
# 2        23.40      0              0      4         49           0      0
# 3        65.52      0              0      0         54           0      0
# 4       330.20      1              2      1          7           0      3
#
#    killStreaks  longestKill  matchDuration  matchType  maxPlace  numGroups  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   groupId          object
#  2   matchId          object
#  3   assists          int64
#  4   boosts           int64
#  5   damageDealt      float64
#  6   DBNOs            int64
#  7   headshotKills    int64
#  8   heals            int64
#  9   killPlace        int64
#  10  killPoints       int64
#  11  kills            int64
#  12  killStreaks      int64
#  13  longestKill      float64
#  14  matchDuration    int64
#  15  matchType        object
#  16  maxPlace         int64
#  17  numGroups        int64
#  18  rankPoints       int64
#  19  revives          int64
#  20  rideDistance     float64
#  21  roadKills        int64
#  22  swimDistance     float64
#  23  teamKills        int64
#  24  vehicleDestroys  int64
#  25  walkDistance     float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1934174 entries, 0 to 1934173
# Data columns (total 28 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   groupId          object
#  2   matchId          object
#  3   assists          int64
#  4   boosts           int64
#  5   damageDealt      float64
#  6   DBNOs            int64
#  7   headshotKills    int64
#  8   heals            int64
#  9   killPlace        int64
#  10  killPoints       int64
#  11  kills            int64
#  12  killStreaks      int64
#  13  longestKill      float64
#  14  matchDuration    int64
#  15  matchType        object
#  16  maxPlace         int64
#  17  numGroups        int64
#  18  rankPoints       int64
#  19  revives          int64
#  20  rideDistance     float64
#  21  roadKills        int64
#  22  swimDistance     float64
#  23  teamKills        int64
#  24  vehicleDestroys  int64
#  25  walkDistance     float64
# ...

# %%
train[train.isna().any(axis=1)]

# %%
train['source']='train'
test['source']='test'

# %%
df=pd.concat([train,test])
df[:4]
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0         0.00      0              0      0         60        1241      0
# 1        91.47      0              0      0         57           0      0
# 2        68.00      0              0      0         47           0      0
# 3        32.90      0              0      0         75           0      0
#
#    killStreaks  longestKill  matchDuration  matchType  maxPlace  numGroups  \
# 0            0          0.0           1306  squad-fpp        28         26
# 1            0          0.0           1777  squad-fpp        26         25
# ...

# %%
df.shape
# Out:
# (6381140, 30)

# %%
df['matchType'].value_counts(normalize=True)*100
# Out:
# squad-fpp           39.308384
# duo-fpp             22.540769
# squad               14.140984
# solo-fpp            12.106614
# duo                  7.122959
# solo                 4.073441
# normal-squad-fpp     0.334345
# crashfpp             0.140853
# normal-duo-fpp       0.112284
# flaretpp             0.049192
# normal-solo-fpp      0.027910
# flarefpp             0.013399
# normal-squad         0.011001
# crashtpp             0.008603
# normal-solo          0.006018
# normal-duo           0.003244
# Name: matchType, dtype: float64

# %%
df['matchType']=df['matchType'].replace({'normal-squad-fpp':'Others','normal-duo-fpp':'Others','normal-solo-fpp':'Others',
                        'crashfpp':'Others','flaretpp':'Others','flarefpp':'Others','crashtpp':'Others',
                        'normal-squad':'Others','normal-solo':'Others','normal-duo':'Others'})

# %%
df['matchType'].value_counts(normalize=True)*100
# Out:
# squad-fpp    39.308384
# duo-fpp      22.540769
# squad        14.140984
# solo-fpp     12.106614
# duo           7.122959
# solo          4.073441
# Others        0.706849
# Name: matchType, dtype: float64

# %%
df.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0         0.00      0              0      0         60        1241      0
# 1        91.47      0              0      0         57           0      0
# 2        68.00      0              0      0         47           0      0
# 3        32.90      0              0      0         75           0      0
# 4       100.00      0              0      0         45           0      1
#
#    killStreaks  longestKill  matchDuration  matchType  maxPlace  numGroups  \
# ...

# %%
df.shape
# Out:
# (6381140, 30)

# %%
df['matchId'].nunique()
# Out:
# 68521

# %%
pubg=df.iloc[0:50000]
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0         0.00      0              0      0         60        1241      0
# 1        91.47      0              0      0         57           0      0
# 2        68.00      0              0      0         47           0      0
# 3        32.90      0              0      0         75           0      0
# 4       100.00      0              0      0         45           0      1
#
#    killStreaks  longestKill  matchDuration  matchType  maxPlace  numGroups  \
# ...

# %%
pubg=df.iloc[0:50000]
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0         0.00      0              0      0         60        1241      0
# 1        91.47      0              0      0         57           0      0
# 2        68.00      0              0      0         47           0      0
# 3        32.90      0              0      0         75           0      0
# 4       100.00      0              0      0         45           0      1
#
#    killStreaks  longestKill  matchDuration  matchType  maxPlace  numGroups  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid");
sns.pairplot(pubg[['damageDealt','DBNOs','winPlacePerc','heals']],kind='scatter')
plt.show()

# %% [markdown]
# Observations:
#
# 1.Chances of Winning increases with high 'heals'
#
# 2.More the 'damageDealt' more the winning percent

# %%
df.isna().sum()/df.shape() *100
# Out:
# Id                  0.000000
# groupId             0.000000
# matchId             0.000000
# assists             0.000000
# boosts              0.000000
# damageDealt         0.000000
# DBNOs               0.000000
# headshotKills       0.000000
# heals               0.000000
# killPlace           0.000000
# killPoints          0.000000
# kills               0.000000
# killStreaks         0.000000
# longestKill         0.000000
# matchDuration       0.000000
# matchType           0.000000
# maxPlace            0.000000
# numGroups           0.000000
# rankPoints          0.000000
# revives             0.000000
# rideDistance        0.000000
# roadKills           0.000000
# swimDistance        0.000000
# teamKills           0.000000
# vehicleDestroys     0.000000
# walkDistance        0.000000
# weaponsAcquired     0.000000
# winPoints           0.000000
# winPlacePerc       43.494271
# source              0.000000
# dtype: float64

# %%
sns.set_style("whitegrid");
sns.pairplot(pubg[['killPlace','kills','killStreaks']],kind='scatter',height=3)
plt.show()

# %% [markdown]
# Observation:
#
# 1.'Killplace' is directly proportional to 'Kills' and 'Killstreaks'

# %%
pubg.describe().T
# Out:
#                    count         mean          std    min     25%        50%  \
# assists          50000.0     0.233880     0.581882    0.0     0.0     0.0000
# boosts           50000.0     1.122680     1.726351    0.0     0.0     0.0000
# damageDealt      50000.0   130.800265   169.934112    0.0     0.0    83.5850
# DBNOs            50000.0     0.658880     1.160252    0.0     0.0     0.0000
# headshotKills    50000.0     0.223100     0.588467    0.0     0.0     0.0000
# heals            50000.0     1.367440     2.651673    0.0     0.0     0.0000
# killPlace        50000.0    47.510960    27.443795    1.0    24.0    47.0000
# killPoints       50000.0   508.544540   627.130684    0.0     0.0     0.0000
# kills            50000.0     0.925500     1.545664    0.0     0.0     0.0000
# killStreaks      50000.0     0.544780     0.715322    0.0     0.0     0.0000
# longestKill      50000.0    22.586286    49.633620    0.0     0.0     0.0000
# ...
